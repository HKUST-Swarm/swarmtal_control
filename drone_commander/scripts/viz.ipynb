# %%
# %matplotlib qt
from swarmtal_csv_parser import *
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
cd = anaylze_csv("/home/xuhao/develop/Swarm_Docker/output/control2024-12-16.csv", 0, 1e10, plot=True)
